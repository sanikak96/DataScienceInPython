# %% [markdown]
# ## COMP41680 Assignment 1 - Task 1 : Data Collection
#
# ### Name: Sanika Kulkarni
# ### Student ID: 21200060
#
#
# In this assignment, I will scrape the data of Top Rated Movies from [The Movie Database](https://www.themoviedb.org/about) through a Web API.
#
# The Movie Database (TMDB) is a community built database having information about movies and TV shows with over 745,000 movies. There is an international focus and the movie data covers movies from many different countires.
#
# To extrat the data from TMDB, the following steps are followed:
# - Create an account
# - Register and fill in information about the intended usage to get API Key
# - Go through the [API Documentation](https://developers.themoviedb.org/3/getting-started/introduction)
# - Use the API Key to extract the necessary data
#
# I have used the data for [top rated movies](https://developers.themoviedb.org/3/movies/get-top-rated-movies) for getting the movie ids. I have then curated more information about these movies using the [movie](https://developers.themoviedb.org/3/movies/get-movie-details) API URL since these requests need movie ids.

# %% [markdown]
# ## Importing required libraries

# %%
import numpy as np
import pandas as pd
import requests
from pandas import json_normalize

# %% [markdown]
# ## Generated the required API key

# %%
apiKey = '08b44048b40963efa3b42ce6dce166cd'

# %% [markdown]
# ## Defining a function to fetch data
#
# There are different categories of movies like top rated movies, latest movies, and so on. Each type has its own API base URL. For this project, I am going to be focusing on top rated movies.
#
# In order to get the movies, I have defined a base URL and a params dictionary to specify the variable parameters of the URL. I have registered on TMDB and received my API Key. The TMDB has movies spread out through number of pages and hence page number is variable that is used for iteration.

# %%
def fetchMovies(pageNo):
  base_url = "https://api.themoviedb.org/3/movie/top_rated"
  params = {
      'api_key':apiKey,
      'page':pageNo
  }
  response_movies = requests.get(base_url,params=params).json()
  return response_movies

# %% [markdown]
# ## Fetching Movie IDs for Top Rated Films

# %%
def get_movie_ids():
    movie_id_list = []
    for j in response:
        for i in j:
           movie_id_list.append(i['id'])
    return movie_id_list

# %%
response = []

#iterate through all pages 
for page in range(1,489):
  response.append(fetchMovies(page)['results']) 

#Get the movie ids of all top rated movies 
movie_ids = get_movie_ids()

# %%
len(movie_ids)
# Out:
# 9760

# %% [markdown]
# ## Extracting information about these top rated films

# %%
movies_df = pd.DataFrame()


for movie_id in movie_ids:
    
    query = "https://api.themoviedb.org/3/movie/" + str(movie_id) + "?api_key=" + apiKey + "&language=en-US"
    response =  requests.get(query)
    if response.status_code==200: 
    #status code ==200 shows that the API call was successful
        movie_results = response.json()
        
        #Create Dataframe
        movies = json_normalize(movie_results)

        
        #Appending to the main dataframes 
        movies_df = pd.concat([movies_df, movies]) 
movies_df.head()
# Out:
#    adult                     backdrop_path belongs_to_collection    budget  \
# 0  False  /wPU78OPN4BYEgWYdXyg0phMee64.jpg                  None  25000000
# 0  False  /90ez6ArvpO8bvpyIngBuwXOqJm5.jpg                  None  13200000
# 0  False  /rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg                  None   6000000
# 0  False  /lp6SmwyNRspEYkkLXFEVuNlCw77.jpg                  None         0
# 0  False  /v5CEt88iDsuoMaW1Q5Msu9UZdEt.jpg                  None         0
#
#                                               genres  \
# 0  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 0  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 0  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 14, '...
# 0  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
#
#                                      homepage      id     imdb_id  \
# 0                                                 278   tt0111161
# 0                                               19404   tt0112870
# 0                http://www.thegodfather.com/     238   tt0068646
# 0      https://www.netflix.com/title/81193214  533514   tt8652818
# 0  https://www.gaga.co.jp/intls/youreyestell/  730154  tt11051974
#
#   original_language                original_title  ...    status  \
# 0                en      The Shawshank Redemption  ...  Released
# 0                hi  दिलवाले दुल्हनिया ले जायेंगे  ...  Released
# 0                en                 The Godfather  ...  Released
# 0                ja          劇場版 ヴァイオレット・エヴァーガーデン  ...  Released
# 0                ja                  きみの瞳が問いかけている  ...  Released
#
#                                              tagline  \
# 0  Fear can hold you prisoner. Hope can set you f...
# 0                Come Fall In love, All Over Again..
# 0                         An offer you can't refuse.
# 0
# 0
#
#                           title  video vote_average vote_count  \
# 0      The Shawshank Redemption  False          8.7      20990
# 0   Dilwale Dulhania Le Jayenge  False          8.7       3519
# 0                 The Godfather  False          8.7      15684
# 0  Violet Evergarden: The Movie  False          8.7        202
# 0                Your Eyes Tell  False          8.7        269
#
#    belongs_to_collection.id  belongs_to_collection.name  \
# 0                       NaN                         NaN
# 0                       NaN                         NaN
# 0                     230.0    The Godfather Collection
# 0                       NaN                         NaN
# 0                       NaN                         NaN
#
#   belongs_to_collection.poster_path belongs_to_collection.backdrop_path
# 0                               NaN                                 NaN
# 0                               NaN                                 NaN
# 0  /9Baumh5J9N1nJUYzNkm0xsgjpwY.jpg    /3WZTxpgscsmoUk81TuECXdFOD0R.jpg
# 0                               NaN                                 NaN
# 0                               NaN                                 NaN
#
# [5 rows x 29 columns]

# %%
movies_df.columns
# Out:
# Index(['adult', 'backdrop_path', 'belongs_to_collection', 'budget', 'genres',
#        'homepage', 'id', 'imdb_id', 'original_language', 'original_title',
#        'overview', 'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count', 'belongs_to_collection.id',
#        'belongs_to_collection.name', 'belongs_to_collection.poster_path',
#        'belongs_to_collection.backdrop_path'],
#       dtype='object')

# %% [markdown]
# ## Converting the movies dataframe to a csv to store it

# %%
movies_df.to_csv("movies_df.csv",index=False)

# %%
# Re-reading it for checking if it was stored correctly
movies_df = pd.read_csv("movies_df.csv")
movies_df.head()
# Out:
#    adult                     backdrop_path  belongs_to_collection    budget  \
# 0  False  /wPU78OPN4BYEgWYdXyg0phMee64.jpg                    NaN  25000000
# 1  False  /90ez6ArvpO8bvpyIngBuwXOqJm5.jpg                    NaN  13200000
# 2  False  /rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg                    NaN   6000000
# 3  False  /lp6SmwyNRspEYkkLXFEVuNlCw77.jpg                    NaN         0
# 4  False  /v5CEt88iDsuoMaW1Q5Msu9UZdEt.jpg                    NaN         0
#
#                                               genres  \
# 0  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 3  [{'id': 16, 'name': 'Animation'}, {'id': 14, '...
# 4  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
#
#                                      homepage      id     imdb_id  \
# 0                                         NaN     278   tt0111161
# 1                                         NaN   19404   tt0112870
# 2                http://www.thegodfather.com/     238   tt0068646
# 3      https://www.netflix.com/title/81193214  533514   tt8652818
# 4  https://www.gaga.co.jp/intls/youreyestell/  730154  tt11051974
#
#   original_language                original_title  ...    status  \
# 0                en      The Shawshank Redemption  ...  Released
# 1                hi  दिलवाले दुल्हनिया ले जायेंगे  ...  Released
# 2                en                 The Godfather  ...  Released
# 3                ja          劇場版 ヴァイオレット・エヴァーガーデン  ...  Released
# 4                ja                  きみの瞳が問いかけている  ...  Released
#
#                                              tagline  \
# 0  Fear can hold you prisoner. Hope can set you f...
# 1                Come Fall In love, All Over Again..
# 2                         An offer you can't refuse.
# 3                                                NaN
# 4                                                NaN
#
#                           title  video vote_average vote_count  \
# 0      The Shawshank Redemption  False          8.7      20990
# 1   Dilwale Dulhania Le Jayenge  False          8.7       3519
# 2                 The Godfather  False          8.7      15684
# 3  Violet Evergarden: The Movie  False          8.7        202
# 4                Your Eyes Tell  False          8.7        269
#
#    belongs_to_collection.id  belongs_to_collection.name  \
# 0                       NaN                         NaN
# 1                       NaN                         NaN
# 2                     230.0    The Godfather Collection
# 3                       NaN                         NaN
# 4                       NaN                         NaN
#
#   belongs_to_collection.poster_path belongs_to_collection.backdrop_path
# 0                               NaN                                 NaN
# 1                               NaN                                 NaN
# 2  /9Baumh5J9N1nJUYzNkm0xsgjpwY.jpg    /3WZTxpgscsmoUk81TuECXdFOD0R.jpg
# 3                               NaN                                 NaN
# 4                               NaN                                 NaN
#
# [5 rows x 29 columns]

# %%
movies_df.shape
# Out:
# (9760, 29)

# %% [markdown]
# **I have thus scraped data about 9760 top rated movies and this is used for further analysis.**
